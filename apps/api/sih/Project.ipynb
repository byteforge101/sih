# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv('/content/student_habits_performance.csv')

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.drop(columns='student_id',axis=1)
df['social_media_hours']=df['netflix_hours']+df['social_media_hours']
df=df.drop(columns='extracurricular_participation',axis=1)
df=df.drop(columns='internet_quality',axis=1)

# %%
df=df.drop(columns='student_id',axis=1)

# %%
df.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23  Female                  0.0                 2.3            1.1
# 1   20  Female                  6.9                 5.1            2.3
# 2   21    Male                  1.4                 4.4            1.3
# 3   23  Female                  1.0                 4.9            1.0
# 4   19  Female                  5.0                 4.9            0.5
#
#   part_time_job  attendance_percentage  sleep_hours diet_quality  \
# 0            No                   85.0          8.0         Fair
# 1            No                   97.3          4.6         Good
# 2            No                   94.8          8.0         Poor
# 3            No                   71.0          9.2         Poor
# 4            No                   90.9          4.9         Fair
#
#    exercise_frequency parental_education_level  mental_health_rating  \
# 0                   6                   Master                     8
# ...

# %%
encoder=LabelEncoder()

# %%
df['gender']=encoder.fit_transform(df['gender'])

# %%
df.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23       0                  0.0                 2.3            1.1
# 1   20       0                  6.9                 5.1            2.3
# 2   21       1                  1.4                 4.4            1.3
# 3   23       0                  1.0                 4.9            1.0
# 4   19       0                  5.0                 4.9            0.5
#
#   part_time_job  attendance_percentage  sleep_hours diet_quality  \
# 0            No                   85.0          8.0         Fair
# 1            No                   97.3          4.6         Good
# 2            No                   94.8          8.0         Poor
# 3            No                   71.0          9.2         Poor
# 4            No                   90.9          4.9         Fair
#
#    exercise_frequency parental_education_level  mental_health_rating  \
# 0                   6                   Master                     8
# ...

# %%
encoder=LabelEncoder()

# %%
df['part_time_job']=encoder.fit_transform(df['part_time_job'])
df['diet_quality']=encoder.fit_transform(df['diet_quality'])
df['parental_education_level']=encoder.fit_transform(df['parental_education_level'])

# %%
df.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23       0                  0.0                 2.3            1.1
# 1   20       0                  6.9                 5.1            2.3
# 2   21       1                  1.4                 4.4            1.3
# 3   23       0                  1.0                 4.9            1.0
# 4   19       0                  5.0                 4.9            0.5
#
#    part_time_job  attendance_percentage  sleep_hours  diet_quality  \
# 0              0                   85.0          8.0             0
# 1              0                   97.3          4.6             1
# 2              0                   94.8          8.0             2
# 3              0                   71.0          9.2             2
# 4              0                   90.9          4.9             0
#
#    exercise_frequency  parental_education_level  mental_health_rating  \
# ...

# %%
from matplotlib import pyplot as plt
df['study_hours_per_day'].plot(kind='hist', bins=20, title='study_hours_per_day')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  netflix_hours  \
# 0   23       0                  0.0                 2.3            1.1
# 1   20       0                  6.9                 5.1            2.3
# 2   21       1                  1.4                 4.4            1.3
# 3   23       0                  1.0                 4.9            1.0
# 4   19       0                  5.0                 4.9            0.5
#
#    part_time_job  attendance_percentage  sleep_hours  diet_quality  \
# 0              0                   85.0          8.0             0
# 1              0                   97.3          4.6             1
# 2              0                   94.8          8.0             2
# 3              0                   71.0          9.2             2
# 4              0                   90.9          4.9             0
#
#    exercise_frequency  parental_education_level  mental_health_rating  \
# ...

# %%
df=df.drop(columns='netflix_hours',axis=1)

# %%
df.head()
# Out:
#    age  gender  study_hours_per_day  social_media_hours  part_time_job  \
# 0   23       0                  0.0                 2.3              0
# 1   20       0                  6.9                 5.1              0
# 2   21       1                  1.4                 4.4              0
# 3   23       0                  1.0                 4.9              0
# 4   19       0                  5.0                 4.9              0
#
#    attendance_percentage  sleep_hours  diet_quality  exercise_frequency  \
# 0                   85.0          8.0             0                   6
# 1                   97.3          4.6             1                   6
# 2                   94.8          8.0             2                   1
# 3                   71.0          9.2             2                   4
# 4                   90.9          4.9             0                   3
#
#    parental_education_level  mental_health_rating  exam_score
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df['age']=scaler.fit_transform(df[['age']])
df['attendance_percentage']=scaler.fit_transform(df[['attendance_percentage']])

# %%
df.head()
# Out:
#         age  gender  study_hours_per_day  social_media_hours  part_time_job  \
# 0  1.084551       0                  0.0                 2.3              0
# 1 -0.215870       0                  6.9                 5.1              0
# 2  0.217604       1                  1.4                 4.4              0
# 3  1.084551       0                  1.0                 4.9              0
# 4 -0.649344       0                  5.0                 4.9              0
#
#    attendance_percentage  sleep_hours  diet_quality  exercise_frequency  \
# 0               0.092426          8.0             0                   6
# 1               1.401696          4.6             1                   6
# 2               1.135584          8.0             2                   1
# 3              -1.397800          9.2             2                   4
# 4               0.720450          4.9             0                   3
#
#    parental_education_level  mental_health_rating  exam_score
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures
model=LinearRegression()
poly=PolynomialFeatures(degree=2)

# %%
df.dtypes
# Out:
# age                         float64
# gender                        int64
# study_hours_per_day         float64
# social_media_hours          float64
# part_time_job                 int64
# attendance_percentage       float64
# sleep_hours                 float64
# diet_quality                  int64
# exercise_frequency            int64
# parental_education_level      int64
# mental_health_rating          int64
# exam_score                  float64
# dtype: object

# %%
for col in df.columns:
  print(col,"-- Misplaced data: ",df[col].isnull().sum())
# Out:
# age -- Misplaced data:  0
# gender -- Misplaced data:  0
# study_hours_per_day -- Misplaced data:  0
# social_media_hours -- Misplaced data:  0
# part_time_job -- Misplaced data:  0
# attendance_percentage -- Misplaced data:  0
# sleep_hours -- Misplaced data:  0
# diet_quality -- Misplaced data:  0
# exercise_frequency -- Misplaced data:  0
# parental_education_level -- Misplaced data:  0
# mental_health_rating -- Misplaced data:  0
# exam_score -- Misplaced data:  0

# %%
X=df.drop(columns='exam_score',axis=1)
Y=df['exam_score']
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (800, 11)
# (200, 11)
# (800,)
# (200,)

# %%
df.shape
# Out:
# (1000, 12)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_test
# Out:
# 521    64.2
# 737    72.7
# 740    79.0
# 660    79.5
# 411    58.2
#        ...
# 408    34.3
# 332    71.2
# 208    75.8
# 613    85.7
# 78     77.3
# Name: exam_score, Length: 200, dtype: float64

# %%
yp=model.predict(X_test)

# %%
mse = mean_squared_error(Y_test, yp)
print(f"Mean Squared Error: {mse}")
df.head()
# Out:
# Mean Squared Error: 26.407102797861512
#         age  gender  study_hours_per_day  social_media_hours  part_time_job  \
# 0  1.084551       0                  0.0                 2.3              0
# 1 -0.215870       0                  6.9                 5.1              0
# 2  0.217604       1                  1.4                 4.4              0
# 3  1.084551       0                  1.0                 4.9              0
# 4 -0.649344       0                  5.0                 4.9              0
#
#    attendance_percentage  sleep_hours  diet_quality  exercise_frequency  \
# 0               0.092426          8.0             0                   6
# 1               1.401696          4.6             1                   6
# 2               1.135584          8.0             2                   1
# 3              -1.397800          9.2             2                   4
# 4               0.720450          4.9             0                   3
#
# ...

# %%
import numpy as np

scaler2=StandardScaler()
age = int(input("Enter age: "))
#female -0 & male-1
gender = int(input("Enter gender (0/1): "))
study_hours_per_day = float(input("Enter study hours per day: "))
social_media_hours = float(input("Enter social media hours: "))
#No=0 & Yes =1
part_time_job = int(input("Enter part time job (0/1): "))
attendance_percentage = float(input("Enter attendance percentage: "))
sleep_hours = float(input("Enter sleep hours: "))
#0-Fair & 1-Good & 2-Poor
diet_quality = int(input("Enter diet quality (1-3): "))
exercise_hours = float(input("Enter exercise hours: "))#per  week
#0-Master & 1-High School & 2-Bachelor & 3-None
parental_education_level = int(input("Enter parental education level (1-5): "))
#Enter mental health rate out of 10
mental_health = int(input("Enter mental health (1-10): "))

# Scale continuous features with fitted scaler

age = scaler.transform([[age]])
age_scaled=age[0][0]
print("age is",age_scaled)
attendance_percentage = scaler.transform([[attendance_percentage]])
attendance_percentage_scaled=attendance_percentage[0][0]
print("attendance_percentage is",attendance_percentage_scaled)

# Input for prediction (must be 2D and numeric only)
input_data = np.array([[age_scaled, gender, study_hours_per_day, social_media_hours,
                         part_time_job, attendance_percentage_scaled, sleep_hours,
                         diet_quality, exercise_hours, parental_education_level,
                         mental_health]])

# Predict
yp = model.predict(input_data)
print("🎯 Predicted Value:", yp)
# Out:
# Enter age: 18
# Enter gender (0/1): 1
# Enter study hours per day: 4
# Enter social media hours: 4
# Enter part time job (0/1): 0
# Enter attendance percentage: 72
# Enter sleep hours: 7
# Enter diet quality (1-3): 3
# Enter exercise hours: 0
# Enter parental education level (1-5): 3
# Enter mental health (1-3): 3
# age is -7.039371943600079
# attendance_percentage is -1.2913557130419004
# 🎯 Predicted Value: [62.88941516]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
# ...

# %%
model.coef_
# Out:
# array([ 0.12314596,  0.20745343,  9.52816721, -2.51888504,  0.35187219,
#         1.38381014,  1.99076387, -0.38647003,  1.31869846, -0.31039509,
#         1.9476269 ])

# %%
import pickle

# %%
with open('model.pkl','wb') as f:
  pickle.dump(model,f)

# %%
with open ('model.pkl','rb') as f:
  mp=pickle.load(f)

# %%
mp.coef_
# Out:
# array([ 0.12314596,  0.20745343,  9.52816721, -2.51888504,  0.35187219,
#         1.38381014,  1.99076387, -0.38647003,  1.31869846, -0.31039509,
#         1.9476269 ])

# %%
correlation=df.corr()
correlation
# Out:
#                                age    gender  study_hours_per_day  \
# age                       1.000000  0.032902             0.003971
# gender                    0.032902  1.000000            -0.016126
# study_hours_per_day       0.003971 -0.016126             1.000000
# social_media_hours       -0.007496  0.027056            -0.006075
# part_time_job            -0.011680  0.035515            -0.029133
# attendance_percentage    -0.026055 -0.021779             0.026264
# sleep_hours               0.037482  0.018843            -0.027757
# diet_quality             -0.011893 -0.001462            -0.071706
# exercise_frequency       -0.003836  0.052808            -0.028701
# parental_education_level  0.000692  0.023286             0.030007
# mental_health_rating     -0.045101 -0.003496            -0.003768
# exam_score               -0.008907 -0.002406             0.825419
#
#                           social_media_hours  part_time_job  \
# ...
